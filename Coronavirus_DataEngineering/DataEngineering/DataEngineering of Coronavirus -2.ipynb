# %% [markdown]
# # Data Engineering of Coronavirus-2

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import re
import nltk

# %% [markdown]
# ### Call in the positive / negative word list

# %%
#Positive word list in lowercase
text_file = open("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\positive.txt", "r")
positive1= text_file.readlines() #convert textfile to list
positive= [x.replace('\n', '') for x in positive1] #extract'\n' in data

#convert all string elements to lowercase
for i in range(len(positive)):
    positive[i] = positive[i].lower()

#Positive word list in Uppercase
positive2=[x.replace('\n', '') for x in positive1] #extract'\n' in data

#convert all string elements to capitial letter in front 
for i in range(len(positive2)):
    positive2[i] = positive2[i].title()
    
#Add the upper and lower text file together
positive3=positive +positive2

positive=positive3
print(positive)
# Out:
# ['abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation', 'accolade', 'accolades', 'accommodative', 'accomodative', 'accomplish', 'accomplished', 'accomplishment', 'accomplishments', 'accurate', 'accurately', 'achievable', 'achievement', 'achievements', 'achievible', 'acumen', 'adaptable', 'adaptive', 'adequate', 'adjustable', 'admirable', 'admirably', 'admiration', 'admire', 'admirer', 'admiring', 'admiringly', 'adorable', 'adore', 'adored', 'adorer', 'adoring', 'adoringly', 'adroit', 'adroitly', 'adulate', 'adulation', 'adulatory', 'advanced', 'advantage', 'advantageous', 'advantageously', 'advantages', 'adventuresome', 'adventurous', 'advocate', 'advocated', 'advocates', 'affability', 'affable', 'affably', 'affectation', 'affection', 'affectionate', 'affinity', 'affirm', 'affirmation', 'affirmative', 'affluence', 'affluent', 'afford', 'affordable', 'affordably', 'afordable', 'agile', 'agilely', 'agility', 'agreeable', 'agreea
# ...

# %%
#Negative word list in lowercase
text_file = open("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\negative.txt", "r")
negative1= text_file.readlines() #convert textfile to list
negative= [x.replace('\n', '') for x in negative1] #extract'\n' in data

#convert all string elements to lowercase
for i in range(len(negative)):
    negative[i] = negative[i].lower()

#Negative word list in Uppercase
negative2=[x.replace('\n', '') for x in negative1] #extract'\n' in data

#convert all string elements to capitial letter in front 
for i in range(len(negative2)):
    negative2[i] = negative2[i].title()
    
#Add the upper and lower text file together
negative3=negative +negative2

negative=negative3
print(negative)
# Out:
# [';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;', '; ', '; opinion lexicon: negative', ';', '; this file contains a list of negative opinion words (or sentiment words).', ';', '; this file and the papers can all be downloaded from ', ';    http://www.cs.uic.edu/~liub/fbs/sentiment-analysis.html', ';', '; if you use this list, please cite one of the following two papers:', ';', ';   minqing hu and bing liu. "mining and summarizing customer reviews." ', ';       proceedings of the acm sigkdd international conference on knowledge ', '2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted', 'aborts', 'abrade', 'abrasive', 'abrupt', 'abruptly', 'abscond', 'absence', 'absent-minded', 'absentee', 'absurd', 'absurdity', 'absurdly', 'absurdness', 'abuse', 'abused', 'abuses', 'abusive', 'abysmal', 'abysmally', 'abyss', 'accidental', 'accost', 'accursed', 'accusation', 'accusations', 'accuse', 'accus
# ...

# %% [markdown]
# ### Call the tweets by country with economic terms

# %%
#US East
file_path = "C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\csv\\coronavirus_date\\us_east_econ.csv"
us_east_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\us_east_econ.csv")
us_east= us_east_df['0']
us_east=us_east.values.tolist()


#US West
us_west_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\us_west_econ.csv")
us_west= us_west_df['0']
us_west=us_west.values.tolist()

#Korea
korea_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\korea_econ.csv")
korea= korea_df['0']
korea=korea.values.tolist()

#Italy
italy_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\italy_econ.csv")
italy= italy_df['0']
italy=italy.values.tolist()

#France
france_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\france_econ.csv")
france= france_df['0']
france=france.values.tolist()

#Swiss
swiss_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\swiss_econ.csv")
swiss= swiss_df['0']
swiss=swiss.values.tolist()

#Iran
iran_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\iran_econ.csv")
iran= iran_df['0']
iran=iran.values.tolist()

#Germany
germany_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\germany_econ.csv")
germany= germany_df['0']
germany=germany.values.tolist()

#UK
uk_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\uk_econ.csv")
uk= uk_df['0']
uk=uk.values.tolist()

# %%
#Spain
spain_df=pd.read_csv("C:\\Users\\13ZD970\\Desktop\\coronavirus_project\\webscraping_code\\econ_csv\\spain_econ_.csv")
spain= spain_df['0']
spain=spain.values.tolist()
print(spain)
# Out:
# ["Michael Gove appears to blame China over lack of UK coronavirus testing. Even if what Gove said was true (of course it wasn't!), there's still no excuse for ignoring advice/experience of other countries, &amp; especially of the WHO. ", 'Spain is not the only country to buy sadly substandard virus equipment from China. But who was the Spanish distributor that acquired deficient test kits - and how much was paid? PM S찼nchez talked about "a super aggressive market." How about opaque?', 'One month ago, Trump said there were only 15 coronavirus cases in the United States and in a few days it would be zero and that proves he is doing a good job Today, Trump said that if 100,000 people die of coronavirus in the United States that proves he is doing a good job ', 'FFS! Might as well have said "We shall fight the coronavirus on the beaches" ', 'As coronavirus cases continue to climb in Spain, Prime Minister Pedro S찼nchez said his government will inject ??bn into the health system and transf
# ...

# %% [markdown]
# ## Scraping Positive terms

# %%
# US East
us_east_positive=[]

for x in range(0,4009):
     for y in range(0,5431):
         if positive[x] in us_east[y]:
             us_east_positive.append(us_east[y])

us_east_positive=set(us_east_positive)
us_east_positive=list(us_east_positive)

df = pd.DataFrame(us_east_positive)
df.to_csv('us_east_positive.csv'.format( int(100/1000)), sep=',')

# %%
# US West
us_west_positive=[]

for x in range(0,4009):
     for y in range(0,2137):
         if positive[x] in us_west[y]:
             us_east_positive.append(us_west[y])

us_west_positive=set(us_west_positive)
us_west_positive=list(us_west_positive)

df = pd.DataFrame(us_west_positive)
df.to_csv('us_west_positive.csv'.format( int(100/1000)), sep=',')


# Italy
italy_positive=[]

for x in range(0,4009):
     for y in range(0,593):
         if positive[x] in italy[y]:
             italy_positive.append(italy[y])

us_west_positive=set(us_west_positive)
us_west_positive=list(us_west_positive)

df = pd.DataFrame(italy_positive)
df.to_csv('italy_positive.csv'.format( int(100/1000)), sep=',')


# Swiss
swiss_positive=[]

for x in range(0,4009):
     for y in range(0,293):
         if positive[x] in swiss[y]:
             swiss_positive.append(swiss[y])

swiss_positive=set(swiss_positive)
swiss_positive=list(swiss_positive)

df = pd.DataFrame(swiss_positive)
df.to_csv('swiss_positive.csv'.format( int(100/1000)), sep=',')


# Spain
spain_positive=[]

for x in range(0,4009):
     for y in range(0,385):
         if positive[x] in spain[y]:
             spain_positive.append(spain[y])

spain_positive=set(spain_positive)
spain_positive=list(spain_positive)

df = pd.DataFrame(spain_positive)
df.to_csv('spain_positive.csv'.format( int(100/1000)), sep=',')



# UK
uk_positive=[]

for x in range(0,4009):
     for y in range(0,2234):
         if positive[x] in uk[y]:
             uk_positive.append(uk[y])

uk_positive=set(uk_positive)
uk_positive=list(uk_positive)

df = pd.DataFrame(uk_positive)
df.to_csv('uk_positive.csv'.format( int(100/1000)), sep=',')



# Germany
germany_positive=[]

for x in range(0,4009):
     for y in range(0,632):
         if positive[x] in germany[y]:
             germany_positive.append(germany[y])

germany_positive=set(germany_positive)
germany_positive=list(germany_positive)

df = pd.DataFrame(germany_positive)
df.to_csv('germany_positive.csv'.format( int(100/1000)), sep=',')



# France
france_positive=[]

for x in range(0,4009):
     for y in range(0,923):
         if positive[x] in france[y]:
             france_positive.append(france[y])

france_positive=set(france_positive)
france_positive=list(france_positive)

df = pd.DataFrame(france_positive)
df.to_csv('france_positive.csv'.format( int(100/1000)), sep=',')


# Iran
iran_positive=[]

for x in range(0,4009):
     for y in range(0,9):
         if positive[x] in iran[y]:
             iran_positive.append(iran[y])

iran_positive=set(iran_positive)
iran_positive=list(iran_positive)

df = pd.DataFrame(iran_positive)
df.to_csv('iran_positive.csv'.format( int(100/1000)), sep=',')

# %%
# US West
us_west_positive=[]

for x in range(0,4009):
     for y in range(0,2137):
         if positive[x] in us_west[y]:
             us_west_positive.append(us_west[y])

us_west_positive=set(us_west_positive)
us_west_positive=list(us_west_positive)

df = pd.DataFrame(us_west_positive)
df.to_csv('us_west_positive.csv'.format( int(100/1000)), sep=',')

# %%
# Italy
italy_positive=[]

for x in range(0,4009):
     for y in range(0,593):
         if positive[x] in italy[y]:
             italy_positive.append(italy[y])

italy_positive=set(italy_positive)
italy_positive=list(italy_positive)

df = pd.DataFrame(italy_positive)
df.to_csv('italy_positive.csv'.format( int(100/1000)), sep=',')

# %%
len(iran_positive)
# Out:
# 2

# %%
len(us_east_positive)
# Out:
# 2308

# %%
len(us_west_positive)
# Out:
# 996

# %%
len(uk_positive)
# Out:
# 1046

# %%
len(germany_positive)
# Out:
# 257

# %%
len(italy_positive)
# Out:
# 250

# %%
len(france_positive)
# Out:
# 339

# %%
len(spain_positive)
# Out:
# 177

# %%
len(swiss_positive)
# Out:
# 116

# %% [markdown]
# ## Scraping Negative Terms

# %%
# US West
us_west_negative=[]

for x in range(0,4009):
     for y in range(0,2137):
         if negative[x] in us_west[y]:
             us_west_negative.append(us_west[y])

us_west_negative=set(us_west_negative)
us_west_negative=list(us_west_negative)
len(us_west_negative)
# Out:
# 1060

# %%
# US East
us_east_negative=[]

for x in range(0,4009):
     for y in range(0,5431):
         if negative[x] in us_east[y]:
             us_east_negative.append(us_east[y])

us_east_negative=set(us_east_negative)
us_east_negative=list(us_east_negative)
len(us_east_negative)
# Out:
# 2546

# %%
# Italy
italy_negative=[]

for x in range(0,4009):
     for y in range(0,593):
         if negative[x] in italy[y]:
             italy_negative.append(italy[y])

italy_negative=set(italy_negative)
italy_negative=list(italy_negative)
len(italy_negative)
# Out:
# 285

# %%
# Spain
spain_negative=[]

for x in range(0,4009):
     for y in range(0,385):
         if negative[x] in spain[y]:
             spain_negative.append(us_west[y])

spain_negative=set(spain_negative)
spain_negative=list(spain_negative)
len(spain_negative)
# Out:
# 287

# %%
# Germany
germany_negative=[]

for x in range(0,4009):
     for y in range(0,632):
         if negative[x] in germany[y]:
             germany_negative.append(germany[y])

germany_negative=set(germany_negative)
germany_negative=list(germany_negative)
len(germany_negative)
# Out:
# 289

# %%
# France
france_negative=[]

for x in range(0,4009):
     for y in range(0,923):
         if negative[x] in france[y]:
             france_negative.append(france[y])

france_negative=set(france_negative)
france_negative=list(france_negative)
len(france_negative)
# Out:
# 421

# %%
# Swiss
swiss_negative=[]

for x in range(0,4009):
     for y in range(0,293):
         if negative[x] in swiss[y]:
             swiss_negative.append(us_west[y])

swiss_negative=set(swiss_negative)
swiss_negative=list(swiss_negative)
len(swiss_negative)
# Out:
# 214

# %%
# UK
uk_negative=[]

for x in range(0,4009):
     for y in range(0,2234):
         if negative[x] in uk[y]:
             uk_negative.append(uk[y])

uk_negative=set(uk_negative)
uk_negative=list(uk_negative)
len(uk_negative)
# Out:
# 1094
